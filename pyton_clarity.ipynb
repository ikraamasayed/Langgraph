# %%
dis_var = 5
print(f"{i}: {id(dis_var)}\n")
yeh_hai_list= [1,2,3,4]


yeh_hai_list.append(dis_var)
for i  in yeh_hai_list:
    print(f"{i}: {id(i)}")

print(id(yeh_hai_list[4]))
dis_var=7
print(id(dis_var))
# Out:
# 5: 140720668640504
#
# 1: 140720668640376
# 2: 140720668640408
# 3: 140720668640440
# 4: 140720668640472
# 5: 140720668640504
# 140720668640504
# 140720668640568

# %%
# Out:
# 0
# 1
# 2
# 3
# 4
